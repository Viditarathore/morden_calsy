# %%
print("the Morden Calculater")
print("Arithmetic operations")
def arthmetic():
  num1 =float(input("enter the number "))
  num2 =float(input("enter the number "))

  operation=input("operation +,-,*,/,%: ")
  if (operation== '+'):
    ans = num1 + num2
    print("addition of number =",ans)
  elif(operation=='-'):
    ans = num1 - num2
    print("substraction of number =",ans)
  elif(operation=='*'):
    ans = num1 * num2
    print("multiplycation of number =",ans)
  elif(operation=='/'):
    ans = num1 / num2
    print("division of number =",ans)
  else:
    ans = num1 % num2
    print("reminder of numbers =",ans)
#function call
arthmetic()
print("-------------------------------------------------")

#for table
def table():
  print("table of integer")
  num3 = int(input("enter the number ="))
  print("table of",num3)
  for i in range(1,11):
    ans = num3 * i
    print(ans)
#function call
table()
print("-------------------------------------------------")

#fectorial of number
print("fectorial of number")
def fectorial():
  num4 = int(input("enter the value"))
  fect=1
  for i in range(1,num4+1):
    fect= fect * i
  print (fect)
#function call
fectorial()
print("-------------------------------------------------")
#calculating the area
print ("area of 2D ")
def area():
  num5=str(input("enter the element(cir,sqr,tri,rect ): "))
  if (num5 == 'cir'):
    radi=float(input("radius="))
    ans=3.14 * radi**2
    print(ans)
  elif(num5== 'sqr'):
    len = float(input("eage of sqr is= "))
    ans =len**2
    print(ans)
  elif(num5== 'tri'):
    len = float(input("length of tri is= "))
    hig = float(input("hight of tri is= "))
    ans =0.5*(len * hig)
    print(ans)

  elif(num5== 'rect'):
    len = float(input("length of rect is= "))
    wid = float(input("width of rect is= "))
    ans =(len * wid)
    print(ans)
#function call
area()
print("-------------------------------------------------")
# Out:
# the Morden Calculater
# Arithmetic operations
# enter the number 45
